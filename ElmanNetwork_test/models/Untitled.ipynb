# %%
import numpy as np

data = np.load('circle.npz')
for key in data.files:
    print(key)
    print(data[key])
# Out:
# Wux
# [[ 1.34189556  0.39622498]
#  [ 0.04031193 -2.4268958 ]
#  [ 0.99400159  0.31213623]
#  [ 1.92890513 -1.05262355]
#  [ 0.45206511 -0.1708726 ]
#  [-4.48347942  0.3145208 ]
#  [-4.67794017 -1.69091892]
#  [-1.78646198  2.4099526 ]
#  [ 0.15135986 -1.22426482]
#  [-2.47318108  0.96029785]
#  [-0.19367015 -0.89048556]
#  [ 0.17290482 -1.07278363]
#  [ 0.89019702  2.37659632]
#  [ 1.09414109  0.1054146 ]
#  [ 0.52534256  3.13328139]
#  [-0.15643121  0.18837855]
#  [ 0.61381056 -0.8435874 ]
#  [-3.28657001 -1.39716481]
#  [-0.19783047  1.2451567 ]
#  [-0.21727687  1.12444274]]
# Wuc
# [[-1.47190742e+00  6.41773218e-01 -1.38118608e+00  3.08658145e-01
#   -8.85441409e-01  1.07012114e+00  9.42953850e-01  3.84344832e-01
#   -1.03591653e+00 -8.86697062e-01  1.78192595e-01  5.63606845e-01
#    2.95764696e+00 -6.30480086e-02  7.05812947e-01 -1.37285305e+00
#   -7.47643780e-01 -1.30315173e-01 -1.32272157e+00  1.46100575e+00]
# ...
